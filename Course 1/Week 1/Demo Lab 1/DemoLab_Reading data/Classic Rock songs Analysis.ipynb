# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd
import sqlite3 as sq3
import pandas.io.sql as pds
print('done')
# Out:
# done

# %% [markdown]
# ### Database Connection

# %%
datapath = 'data/classic_rock.db'
con = sq3.Connection(datapath)

# %% [markdown]
# ### Reading Data

# %%
query = '''
SELECT *
FROM rock_songs;
'''
observations = pds.read_sql(query,con)
observations
# Out:
#                                              Song        Artist  Release_Year  \
# 0                                Caught Up in You   .38 Special        1982.0
# 1                                 Hold On Loosely   .38 Special        1981.0
# 2                          Rockin' Into the Night   .38 Special        1980.0
# 3                               Art For Arts Sake          10cc        1975.0
# 4                                      Kryptonite  3 Doors Down        2000.0
# ...                                           ...           ...           ...
# 1645                            Sharp Dressed Man        ZZ Top        1983.0
# 1646                            Tube Snake Boogie        ZZ Top        1981.0
# 1647                                         Tush        ZZ Top        1975.0
# 1648                                   TV Dinners        ZZ Top        1983.0
# 1649  WAITIN' FOR THE BUS/JESUS JUST LEFT CHICAGO        ZZ Top        1973.0
#
#       PlayCount
# ...

# %% [markdown]
# ### Counting the rows of data

# %%
counting = '''
SELECT COUNT(*) FROM rock_songs; '''
counting_op = pds.read_sql(counting, con)
counting_op
# Out:
#    COUNT(*)
# 0      1650

# %%
query = ''' SELECT Artist, Release_Year, COUNT(*) AS num_songs, AVG(PlayCount) AS avg_plays  
    FROM rock_songs
    GROUP BY Artist, Release_Year
    ORDER BY num_songs desc;
'''
observations_1 = pds.read_sql(query,con,
                           coerce_float = True,
                           parse_dates = ['Release_Year'],
                           chunksize = 5)
observations = pds.read_sql(query, con)

for index,observations in enumerate(observations_1):
    if index < 5:
        print(f'Observations index: {index}'.format(index))
        display(observations)
# Out:
# Observations index: 0
#          Artist        Release_Year  num_songs  avg_plays
# 0   The Beatles 1970-01-01 00:32:47         23   6.565217
# 1  Led Zeppelin 1970-01-01 00:32:49         18  21.000000
# 2   The Beatles 1970-01-01 00:32:45         15   3.800000
# 3   The Beatles 1970-01-01 00:32:48         13  13.000000
# 4   The Beatles 1970-01-01 00:32:49         13  15.000000
# Observations index: 1
#          Artist        Release_Year  num_songs  avg_plays
# 0  Led Zeppelin 1970-01-01 00:32:50         12  13.166667
# 1  Led Zeppelin 1970-01-01 00:32:55         12  14.166667
# 2    Pink Floyd 1970-01-01 00:32:59         11  41.454545
# 3    Pink Floyd 1970-01-01 00:32:53         10  29.100000
# 4     The Doors 1970-01-01 00:32:47         10  28.900000
# Observations index: 2
#           Artist        Release_Year  num_songs  avg_plays
# 0  Fleetwood Mac 1970-01-01 00:32:57          9  35.666667
# 1   Jimi Hendrix 1970-01-01 00:32:47          9  24.888889
# ...
